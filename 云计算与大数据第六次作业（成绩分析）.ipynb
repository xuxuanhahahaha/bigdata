# %%
pip install datascience
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datascience 
import matplotlib
matplotlib.use('TkAgg')
from datascience import *
import matplotlib.pyplot as plt
# %matplotlib inline


def extract_rank(data,name):
    temp=data.where('姓名',are.equal_to(name)).column(11).item(0)
    return temp

D1=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211105-utf-8.csv')
D2=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211106-utf-8.csv')
D3=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211107-utf-8.csv')
D4=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211108-utf-8.csv')
D5=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211109-utf-8.csv')
D6=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211109-1-utf-8.csv')
D7=Table.read_table('C:/Users/Lenovo/Documents/Tencent Files/3173118572/FileRecv/20211110-utf-8.csv')


name1 = input('请输入待查询的名字：')
name2 = input('请输入待查询的名字：')

rank1=extract_rank(D1,name1)
rank2=extract_rank(D2,name1)
rank3=extract_rank(D3,name1)
rank4=extract_rank(D4,name1)
rank5=extract_rank(D5,name1)
rank6=extract_rank(D6,name1)
rank7=extract_rank(D7,name1)

rank11=extract_rank(D1,name2)
rank22=extract_rank(D2,name2)
rank33=extract_rank(D3,name2)
rank44=extract_rank(D4,name2)
rank55=extract_rank(D5,name2)
rank66=extract_rank(D6,name2)
rank77=extract_rank(D7,name2)

rank_array1=make_array(rank1,rank2,rank3,rank4,rank5,rank6,rank7)
rank_array2=make_array(rank11,rank22,rank33,rank44,rank55,rank66,rank77)
result1=Table().with_columns('成绩1',rank_array1,'成绩2',rank_array2)
#result1


plt.plot(make_array(1,2,3,4,5,6,7),rank_array1,'o--',label=name1)
plt.plot(make_array(1,2,3,4,5,6,7),rank_array2,'o--r',label=name2)
plt.title(name1 +'和'+ name2 + '历次成绩趋势图')
plt.xlabel('历次考试')
plt.ylabel('历次考试成绩')
plt.axis([0,10,0,750])
plt.legend(loc='upper right')
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.grid()
plt.show()
# Out:
# 请输入待查询的名字：刘翔
# 请输入待查询的名字：王宣
